# %%
import pandas as pd

# %%
file1 = pd.read_csv(r"C:\Users\Admin\Downloads\Pandas Session 2 join Resources 16922586001 (1).txt")

# %%
file1
# Out:
#      use_id  user_id platform  platform_version                  device  \
# 0     22782    26980      ios              10.2               iPhone7,2
# 1     22783    29628  android               6.0                 Nexus 5
# 2     22784    28473  android               5.1                SM-G903F
# 3     22785    15200      ios              10.2               iPhone7,2
# 4     22786    28239  android               6.0               ONE E1003
# ..      ...      ...      ...               ...                     ...
# 267   23049    29725  android               6.0                SM-G900F
# 268   23050    29726      ios              10.2               iPhone7,2
# 269   23051    29726      ios              10.2               iPhone7,2
# 270   23052    29727      ios              10.1               iPhone8,4
# 271   23053    20257  android               5.1  Vodafone Smart ultra 6
#
#      use_type_id
# 0              2
# 1              3
# 2              1
# 3              3
# ...

# %%
file2 = pd.read_csv(r"C:\Users\Admin\Downloads\Pandas Session 2 join Resources 16922586000 (1).txt")

# %%
file2
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
# [240 rows x 4 columns]

# %%
pd.merge(file2,file1)
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 154                   198.59                   90.49     5191.12   23043
# 155                   198.59                   90.49     3114.67   23044
# 156                   106.65                   82.13     5191.12   23046
# 157                   344.53                   20.53      519.12   23049
# 158                    42.75                   46.83     5191.12   23053
#
#      user_id platform  platform_version                  device  use_type_id
# ...

# %%
pd.merge(file2,file1,how="left")
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
#      user_id platform  platform_version    device  use_type_id
# ...

# %%
pd.merge(file2,file1,how="right")
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                        NaN                     NaN         NaN   22782
# 1                        NaN                     NaN         NaN   22783
# 2                        NaN                     NaN         NaN   22784
# 3                        NaN                     NaN         NaN   22785
# 4                        NaN                     NaN         NaN   22786
# ..                       ...                     ...         ...     ...
# 267                   344.53                   20.53      519.12   23049
# 268                      NaN                     NaN         NaN   23050
# 269                      NaN                     NaN         NaN   23051
# 270                      NaN                     NaN         NaN   23052
# 271                    42.75                   46.83     5191.12   23053
#
#      user_id platform  platform_version                  device  use_type_id
# ...

# %%
pd.merge(file2,file1,how="left",on="use_id")
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
#      user_id platform  platform_version    device  use_type_id
# ...

# %%
file1.head(2)
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3

# %%
file2.head(2)
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788

# %%
data = pd.merge(file2,file1)

# %%
mer = pd.merge(data[["outgoing_mins_per_month","use_id"]],data[["device","use_id"]],how="left",on="use_id")

# %%
mer
# Out:
#      outgoing_mins_per_month  use_id                  device
# 0                      21.97   22787                GT-I9505
# 1                    1710.08   22788                SM-G930F
# 2                    1710.08   22789                SM-G930F
# 3                      94.46   22790                   D2303
# 4                      71.59   22792                SM-G361F
# ..                       ...     ...                     ...
# 154                   198.59   23043                SM-G900F
# 155                   198.59   23044                SM-G900F
# 156                   106.65   23046              Moto G (4)
# 157                   344.53   23049                SM-G900F
# 158                    42.75   23053  Vodafone Smart ultra 6
#
# [159 rows x 3 columns]

# %%
# Creating first dataframe 
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}) 
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
# Creating second dataframe 
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'], 
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C4', 'C5', 'C6', 'C7'], 
                    'D': ['D4', 'D5', 'D6', 'D7']})
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
# Creating third dataframe 
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'], 
                    'B': ['B8', 'B9', 'B10', 'B11'], 
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']})
df3
# Out:
#      A    B    C    D
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
data1 = pd.concat([df1,df2,df3])

# %%
data1
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A4   B4   C4   D4
# 1   A5   B5   C5   D5
# 2   A6   B6   C6   D6
# 3   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
data1.reset_index()
# Out:
#     index    A    B    C    D
# 0       0   A0   B0   C0   D0
# 1       1   A1   B1   C1   D1
# 2       2   A2   B2   C2   D2
# 3       3   A3   B3   C3   D3
# 4       0   A4   B4   C4   D4
# 5       1   A5   B5   C5   D5
# 6       2   A6   B6   C6   D6
# 7       3   A7   B7   C7   D7
# 8       0   A8   B8   C8   D8
# 9       1   A9   B9   C9   D9
# 10      2  A10  B10  C10  D10
# 11      3  A11  B11  C11  D11

# %%
data1
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A4   B4   C4   D4
# 1   A5   B5   C5   D5
# 2   A6   B6   C6   D6
# 3   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
data = pd.read_excel(r"C:\Users\Admin\OneDrive\Desktop\Library Resources\Pandas\Pandas Session 1 Resources 16922586003.xlsx")

# %%
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
data.groupby("Sales_Channel")["Country"].count()
# Out:
# Sales_Channel
# Offline    50
# Online     50
# Name: Country, dtype: int64

# %%
data.groupby(["Sales_Channel","Country"])[["Order_Priority","Region"]].count()
# Out:
#                               Order_Priority  Region
# Sales_Channel Country
# Offline       Angola                       1       1
#               Australia                    2       2
#               Austria                      1       1
#               Belize                       1       1
#               Cameroon                     1       1
# ...                                      ...     ...
# Online        Syria                        1       1
#               The Gambia                   1       1
#               Turkmenistan                 1       1
#               United Kingdom               1       1
#               Zambia                       1       1
#
# [87 rows x 2 columns]

# %%
data.groupby(["Order_Priority","Sales_Channel"])[["Unit_Cost","Total_Profit"]].mean()
# Out:
#                                Unit_Cost   Total_Profit
# Order_Priority Sales_Channel
# C              Offline        119.486923  278870.439231
#                Online         134.111111  347001.416667
# H              Offline        228.757647  580930.938235
#                Online         139.936923  539674.894615
# L              Offline        294.681667  528441.738333
#                Online         143.524667  301161.800000
# M              Offline        232.845000  634785.518750
#                Online         237.276923  353173.719231

# %%
data.groupby(["Sales_Channel","Order_Priority"])[["Unit_Cost","Total_Profit"]].mean()
# Out:
#                                Unit_Cost   Total_Profit
# Sales_Channel Order_Priority
# Offline       C               119.486923  278870.439231
#               H               228.757647  580930.938235
#               L               294.681667  528441.738333
#               M               232.845000  634785.518750
# Online        C               134.111111  347001.416667
#               H               139.936923  539674.894615
#               L               143.524667  301161.800000
#               M               237.276923  353173.719231

# %%
data.groupby(["Sales_Channel","Order_Priority"])[["Unit_Cost","Total_Profit"]].count()
# Out:
#                               Unit_Cost  Total_Profit
# Sales_Channel Order_Priority
# Offline       C                      13            13
#               H                      17            17
#               L                      12            12
#               M                       8             8
# Online        C                       9             9
#               H                      13            13
#               L                      15            15
#               M                      13            13

# %%
data.groupby(["Sales_Channel","Order_Priority"])[["Unit_Cost","Total_Profit"]].agg(["mean","count","median"])
# Out:
#                                Unit_Cost                  Total_Profit        \
#                                     mean count   median           mean count
# Sales_Channel Order_Priority
# Offline       C               119.486923    13   35.840  278870.439231    13
#               H               228.757647    17  159.420  580930.938235    17
#               L               294.681667    12  382.935  528441.738333    12
#               M               232.845000     8  211.375  634785.518750     8
# Online        C               134.111111     9   35.840  347001.416667     9
#               H               139.936923    13  117.110  539674.894615    13
#               L               143.524667    15   90.930  301161.800000    15
#               M               237.276923    13  117.110  353173.719231    13
#
#
#                                   median
# Sales_Channel Order_Priority
# Offline       C               127722.960
#               H               449159.040
# ...

# %%
pd.pivot_table(data,index=["Sales_Channel","Order_Priority"],aggfunc="count")
# Out:
#                               Country  Item_Type  Region  Ship_Date  \
# Sales_Channel Order_Priority
# Offline       C                    13         13      13         13
#               H                    17         17      17         17
#               L                    12         12      12         12
#               M                     8          8       8          8
# Online        C                     9          9       9          9
#               H                    13         13      13         13
#               L                    15         15      15         15
#               M                    13         13      13         13
#
#                               Total_Profit  Total_Revenue  Unit_Cost
# Sales_Channel Order_Priority
# Offline       C                         13             13         13
#               H                         17             17         17
#               L                         12             12         12
# ...

# %%
pd.pivot_table(data,index=["Sales_Channel","Order_Priority"],columns=["Unit_Cost","Total_Profit"],aggfunc="count")
# Out:
#                                 Country                                   \
# Unit_Cost                        6.92
# Total_Profit                 1258.02    1621.93    5270.67    9119.44
# Sales_Channel Order_Priority
# Offline       C                     NaN        NaN        NaN        NaN
#               H                     NaN        NaN        NaN        NaN
#               L                     NaN        NaN        NaN        NaN
#               M                     NaN        NaN        NaN        NaN
# Online        C                     NaN        NaN        NaN        NaN
#               H                     NaN        NaN        1.0        NaN
#               L                     NaN        1.0        NaN        1.0
#               M                     1.0        NaN        NaN        NaN
#
#                                                                           \
# Unit_Cost
# Total_Profit                 13009.18   14031.02   15103.47   18405.17
# ...

# %%
data.groupby("Region")[["Total_Profit","Unit_Cost"]].mean()
# Out:
#                                     Total_Profit   Unit_Cost
# Region
# Asia                               555804.170000  239.587273
# Australia and Oceania              429287.275455  154.744545
# Central America and the Caribbean  406701.121429  157.817143
# Europe                             503769.937727  223.166364
# Middle East and North Africa       576119.186000  152.450000
# North America                      485980.920000  205.293333
# Sub_Saharan Africa                 338422.538889  183.677500

# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\Admin\OneDrive\Desktop\Library Resources\Pandas\Pandas Session 1 Resources 16922586003.xlsx")

# %%
pd.crosstab(data["Region"],data["Sales_Channel"])
# Out:
# Sales_Channel                      Offline  Online
# Region
# Asia                                     6       5
# Australia and Oceania                    4       7
# Central America and the Caribbean        5       2
# Europe                                   9      13
# Middle East and North Africa             2       8
# North America                            3       0
# Sub_Saharan Africa                      21      15

# %%
pd.crosstab(data["Sales_Channel"],data["Item_Type"])
# Out:
# Item_Type      Baby Food  Beverages  Cereal  Clothes  Cosmetics  Fruits  \
# Sales_Channel
# Offline                3          6       3        6          7       2
# Online                 4          2       4        7          6       8
#
# Item_Type      Household  Meat  Office Supplies  Personal Care  Snacks  \
# Sales_Channel
# Offline                8     0                6              7       0
# Online                 1     2                6              3       3
#
# Item_Type      Vegetables
# Sales_Channel
# Offline                 2
# Online                  4
