# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\Admin\OneDrive\Desktop\Library Resources\Pandas\Pandas Session 1 Resources 16922586003.xlsx")
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
data1 = data.copy()

# %%
data.drop("Region",axis=1)
# Out:
#                   Country        Item_Type Sales_Channel Order_Priority  \
# 0                  Tuvalu        Baby Food       Offline              H
# 1                 Grenada           Cereal        Online              C
# 2                  Russia  Office Supplies       Offline              L
# 3   Sao Tome and Principe           Fruits        Online              C
# 4                  Rwanda  Office Supplies       Offline              L
# ..                    ...              ...           ...            ...
# 95                   Mali          Clothes        Online              M
# 96               Malaysia           Fruits       Offline              L
# 97           Sierra Leone       Vegetables       Offline              C
# 98                 Mexico    Personal Care       Offline              M
# 99             Mozambique        Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# ...

# %%
data.head(2)
# Out:
#                               Region  Country  Item_Type Sales_Channel  \
# 0              Australia and Oceania   Tuvalu  Baby Food       Offline
# 1  Central America and the Caribbean  Grenada     Cereal        Online
#
#   Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 0              H 2010-06-27     159.42      2533654.0     951410.50
# 1              C 2012-09-15     117.11       576782.8     248406.36

# %%
data.drop("Region",axis=1,inplace=True)

# %%
data
# Out:
#                   Country        Item_Type Sales_Channel Order_Priority  \
# 0                  Tuvalu        Baby Food       Offline              H
# 1                 Grenada           Cereal        Online              C
# 2                  Russia  Office Supplies       Offline              L
# 3   Sao Tome and Principe           Fruits        Online              C
# 4                  Rwanda  Office Supplies       Offline              L
# ..                    ...              ...           ...            ...
# 95                   Mali          Clothes        Online              M
# 96               Malaysia           Fruits       Offline              L
# 97           Sierra Leone       Vegetables       Offline              C
# 98                 Mexico    Personal Care       Offline              M
# 99             Mozambique        Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# ...

# %%
data.drop([0,1,2])
# Out:
#                   Country        Item_Type Sales_Channel Order_Priority  \
# 3   Sao Tome and Principe           Fruits        Online              C
# 4                  Rwanda  Office Supplies       Offline              L
# 5         Solomon Islands        Baby Food        Online              C
# 6                  Angola        Household       Offline              M
# 7            Burkina Faso       Vegetables        Online              H
# ..                    ...              ...           ...            ...
# 95                   Mali          Clothes        Online              M
# 96               Malaysia           Fruits       Offline              L
# 97           Sierra Leone       Vegetables       Offline              C
# 98                 Mexico    Personal Care       Offline              M
# 99             Mozambique        Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# ...

# %%
data.drop(0,inplace=True)

# %%
data
# Out:
#                   Country        Item_Type Sales_Channel Order_Priority  \
# 1                 Grenada           Cereal        Online              C
# 2                  Russia  Office Supplies       Offline              L
# 3   Sao Tome and Principe           Fruits        Online              C
# 4                  Rwanda  Office Supplies       Offline              L
# 5         Solomon Islands        Baby Food        Online              C
# ..                    ...              ...           ...            ...
# 95                   Mali          Clothes        Online              M
# 96               Malaysia           Fruits       Offline              L
# 97           Sierra Leone       Vegetables       Offline              C
# 98                 Mexico    Personal Care       Offline              M
# 99             Mozambique        Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# ...

# %%
for i in range(1,5):
    data.drop(i,inplace=True)

# %%
data
# Out:
#                   Country      Item_Type Sales_Channel Order_Priority  \
# 5         Solomon Islands      Baby Food        Online              C
# 6                  Angola      Household       Offline              M
# 7            Burkina Faso     Vegetables        Online              H
# 8   Republic of the Congo  Personal Care       Offline              M
# 9                 Senegal         Cereal        Online              H
# ..                    ...            ...           ...            ...
# 95                   Mali        Clothes        Online              M
# 96               Malaysia         Fruits       Offline              L
# 97           Sierra Leone     Vegetables       Offline              C
# 98                 Mexico  Personal Care       Offline              M
# 99             Mozambique      Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 5  2015-02-21     159.42      759202.72     285087.64
# ...

# %%
data.iloc[[5,6,7,8],[0,1,2]]
# Out:
#        Country   Item_Type Sales_Channel
# 10  Kyrgyzstan  Vegetables        Online
# 11  Cape Verde     Clothes       Offline
# 12  Bangladesh     Clothes        Online
# 13    Honduras   Household       Offline

# %%
data
# Out:
#                   Country      Item_Type Sales_Channel Order_Priority  \
# 5         Solomon Islands      Baby Food        Online              C
# 6                  Angola      Household       Offline              M
# 7            Burkina Faso     Vegetables        Online              H
# 8   Republic of the Congo  Personal Care       Offline              M
# 9                 Senegal         Cereal        Online              H
# ..                    ...            ...           ...            ...
# 95                   Mali        Clothes        Online              M
# 96               Malaysia         Fruits       Offline              L
# 97           Sierra Leone     Vegetables       Offline              C
# 98                 Mexico  Personal Care       Offline              M
# 99             Mozambique      Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 5  2015-02-21     159.42      759202.72     285087.64
# ...

# %%
data.drop(["Country","Item_Type","Sales_Channel"],axis=1,inplace=True)

# %%
data
# Out:
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 5               C 2015-02-21     159.42      759202.72     285087.64
# 6               M 2011-04-27     502.54     2798046.49     693911.51
# 7               H 2012-07-27      90.93     1245112.92     510216.66
# 8               M 2015-08-25      56.67      496101.10     152114.20
# 9               H 2014-05-30     117.11     1356180.10     584073.87
# ..            ...        ...        ...            ...           ...
# 95              M 2011-03-09      35.84       97040.64      65214.72
# 96              L 2011-12-28       6.92       58471.11      15103.47
# 97              C 2016-06-29      90.93      228779.10      93748.05
# 98              M 2015-08-08      56.67      471336.91     144521.02
# 99              L 2012-02-15     502.54     3586605.09     889472.91
#
# [95 rows x 5 columns]

# %%
data.drop([5,7,9],inplace=True)

# %%
data
# Out:
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 6               M 2011-04-27     502.54     2798046.49     693911.51
# 8               M 2015-08-25      56.67      496101.10     152114.20
# 10              H 2011-12-07      90.93       19103.44       7828.12
# 11              H 2014-08-19      35.84      455479.04     306097.92
# 12              L 2017-01-03      35.84      902980.64     606834.72
# ..            ...        ...        ...            ...           ...
# 95              M 2011-03-09      35.84       97040.64      65214.72
# 96              L 2011-12-28       6.92       58471.11      15103.47
# 97              C 2016-06-29      90.93      228779.10      93748.05
# 98              M 2015-08-08      56.67      471336.91     144521.02
# 99              L 2012-02-15     502.54     3586605.09     889472.91
#
# [92 rows x 5 columns]

# %%
data.drop(index=[6,8],columns=["Order_Priority","Unit_Cost"],inplace=True)

# %%
data
# Out:
#     Ship_Date  Total_Revenue  Total_Profit
# 10 2011-12-07       19103.44       7828.12
# 11 2014-08-19      455479.04     306097.92
# 12 2017-01-03      902980.64     606834.72
# 13 2017-02-13     5997054.98    1487261.02
# 14 2014-02-23      400558.73     122819.06
# ..        ...            ...           ...
# 95 2011-03-09       97040.64      65214.72
# 96 2011-12-28       58471.11      15103.47
# 97 2016-06-29      228779.10      93748.05
# 98 2015-08-08      471336.91     144521.02
# 99 2012-02-15     3586605.09     889472.91
#
# [90 rows x 3 columns]

# %%
a = {
    "Ship_Date":"A",
    "Total_Revenue":"B"
}

# %%
data.rename(columns=a)
# Out:
#             A           B  Total_Profit
# 10 2011-12-07    19103.44       7828.12
# 11 2014-08-19   455479.04     306097.92
# 12 2017-01-03   902980.64     606834.72
# 13 2017-02-13  5997054.98    1487261.02
# 14 2014-02-23   400558.73     122819.06
# ..        ...         ...           ...
# 95 2011-03-09    97040.64      65214.72
# 96 2011-12-28    58471.11      15103.47
# 97 2016-06-29   228779.10      93748.05
# 98 2015-08-08   471336.91     144521.02
# 99 2012-02-15  3586605.09     889472.91
#
# [90 rows x 3 columns]

# %%
data
# Out:
#     Ship_Date  Total_Revenue  Total_Profit
# 10 2011-12-07       19103.44       7828.12
# 11 2014-08-19      455479.04     306097.92
# 12 2017-01-03      902980.64     606834.72
# 13 2017-02-13     5997054.98    1487261.02
# 14 2014-02-23      400558.73     122819.06
# ..        ...            ...           ...
# 95 2011-03-09       97040.64      65214.72
# 96 2011-12-28       58471.11      15103.47
# 97 2016-06-29      228779.10      93748.05
# 98 2015-08-08      471336.91     144521.02
# 99 2012-02-15     3586605.09     889472.91
#
# [90 rows x 3 columns]

# %%
data.rename(columns=a,inplace=True)

# %%
data
# Out:
#             A           B  Total_Profit
# 10 2011-12-07    19103.44       7828.12
# 11 2014-08-19   455479.04     306097.92
# 12 2017-01-03   902980.64     606834.72
# 13 2017-02-13  5997054.98    1487261.02
# 14 2014-02-23   400558.73     122819.06
# ..        ...         ...           ...
# 95 2011-03-09    97040.64      65214.72
# 96 2011-12-28    58471.11      15103.47
# 97 2016-06-29   228779.10      93748.05
# 98 2015-08-08   471336.91     144521.02
# 99 2012-02-15  3586605.09     889472.91
#
# [90 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['A', 'B', 'Total_Profit'], dtype='object')

# %%
data[['B','Total_Profit','A']]
# Out:
#              B  Total_Profit          A
# 10    19103.44       7828.12 2011-12-07
# 11   455479.04     306097.92 2014-08-19
# 12   902980.64     606834.72 2017-01-03
# 13  5997054.98    1487261.02 2017-02-13
# 14   400558.73     122819.06 2014-02-23
# ..         ...           ...        ...
# 95    97040.64      65214.72 2011-03-09
# 96    58471.11      15103.47 2011-12-28
# 97   228779.10      93748.05 2016-06-29
# 98   471336.91     144521.02 2015-08-08
# 99  3586605.09     889472.91 2012-02-15
#
# [90 rows x 3 columns]

# %%
data = data1.copy()

# %%
data["Unit_Cost"].mean()
# Out:
# np.float64(191.048)

# %%
data["Order_Priority"].mode()
# Out:
# 0    H
# Name: Order_Priority, dtype: object

# %%
data[data["Country"] == "Russia"].count()
# Out:
# Region            1
# Country           1
# Item_Type         1
# Sales_Channel     1
# Order_Priority    1
# Ship_Date         1
# Unit_Cost         1
# Total_Revenue     1
# Total_Profit      1
# dtype: int64

# %%
data[data["Order_Priority"] == 'H']
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 7                  Sub_Saharan Africa           Burkina Faso       Vegetables
# 9                  Sub_Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# 11                 Sub_Saharan Africa             Cape Verde          Clothes
# 13  Central America and the Caribbean               Honduras        Household
# 21                             Europe               Portugal        Baby Food
# 23              Australia and Oceania            New Zealand           Fruits
# 25                             Europe                 France        Cosmetics
# 33                               Asia                Myanmar        Household
# 40                 Sub_Saharan Africa                  Niger    Personal Care
# ...

# %%
data["Sales_Channel"].mode()
# Out:
# 0    Offline
# 1     Online
# Name: Sales_Channel, dtype: object

# %%
data[(data["Sales_Channel"] == "Online") & (data["Order_Priority"] == "H")]
# Out:
#                           Region       Country      Item_Type Sales_Channel  \
# 7             Sub_Saharan Africa  Burkina Faso     Vegetables        Online
# 9             Sub_Saharan Africa       Senegal         Cereal        Online
# 10                          Asia    Kyrgyzstan     Vegetables        Online
# 21                        Europe      Portugal      Baby Food        Online
# 23         Australia and Oceania   New Zealand         Fruits        Online
# 25                        Europe        France      Cosmetics        Online
# 40            Sub_Saharan Africa         Niger  Personal Care        Online
# 43                        Europe      Slovakia     Vegetables        Online
# 44                          Asia       Myanmar        Clothes        Online
# 73            Sub_Saharan Africa      Djibouti         Cereal        Online
# 79         Australia and Oceania        Samoa       Cosmetics        Online
# ...

# %%
data[(data["Sales_Channel"] == "Online") & (data["Order_Priority"] == "H") & (data["Region"] == "Asia")]
# Out:
#    Region     Country   Item_Type Sales_Channel Order_Priority  Ship_Date  \
# 10   Asia  Kyrgyzstan  Vegetables        Online              H 2011-12-07
# 44   Asia     Myanmar     Clothes        Online              H 2015-11-18
#
#     Unit_Cost  Total_Revenue  Total_Profit
# 10      90.93       19103.44       7828.12
# 44      35.84      648030.40     435499.20

# %%
data["Unit_Cost"].std()
# Out:
# 188.20818124855495

# %%
data[["Unit_Cost","Total_Profit"]].std()
# Out:
# Unit_Cost          188.208181
# Total_Profit    438537.907060
# dtype: float64

# %%
data1 = pd.read_csv(r"C:\Users\Admin\Downloads\Pandas last fillna  Resources 16922587502 (1).txt")

# %%
data1
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
data1.isnull()
# Out:
#     Date    Age  Sales    Day
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True  False
# 3  False  False  False   True
# 4  False   True   True  False
# 5  False  False   True  False
# 6  False   True   True   True
# 7  False  False  False  False
# 8  False  False  False  False

# %%
data1.fillna("yash")
# Out:
#          Date   Age Sales        Day
# 0  01/01/2019  32.0   6.0     Monday
# 1  01/02/2019  yash   9.0    Tuesday
# 2  01/10/2019  28.0  yash  Wednesday
# 3  01/11/2019  32.0   7.0       yash
# 4  01/12/2019  yash  yash     Monday
# 5  01/16/2019  32.0  yash    Tuesday
# 6  01/17/2019  yash  yash       yash
# 7  01/20/2019  34.0   8.0   Thrusday
# 8  01/21/2019  40.0  12.0    Tuesday

# %%
data1.fillna(7)
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   7.0    9.0    Tuesday
# 2  01/10/2019  28.0    7.0  Wednesday
# 3  01/11/2019  32.0    7.0          7
# 4  01/12/2019   7.0    7.0     Monday
# 5  01/16/2019  32.0    7.0    Tuesday
# 6  01/17/2019   7.0    7.0          7
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
data1.fillna(method="ffill")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5188\287217370.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1.fillna(method="ffill")
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  32.0    9.0    Tuesday
# 2  01/10/2019  28.0    9.0  Wednesday
# 3  01/11/2019  32.0    7.0  Wednesday
# 4  01/12/2019  32.0    7.0     Monday
# 5  01/16/2019  32.0    7.0    Tuesday
# 6  01/17/2019  32.0    7.0    Tuesday
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
data1.fillna(method="bfill")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5188\2411069616.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1.fillna(method="bfill")
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  28.0    9.0    Tuesday
# 2  01/10/2019  28.0    7.0  Wednesday
# 3  01/11/2019  32.0    7.0     Monday
# 4  01/12/2019  32.0    8.0     Monday
# 5  01/16/2019  32.0    8.0    Tuesday
# 6  01/17/2019  34.0    8.0   Thrusday
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
data1["Day"].mode()[0]
# Out:
# 'Tuesday'

# %%
a = {"Age":data1["Age"].mean(),"Sales":data1["Sales"].mean(),"Day":data1["Day"].mode()[0]}

# %%
data1.fillna(a)
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  33.0    9.0    Tuesday
# 2  01/10/2019  28.0    8.4  Wednesday
# 3  01/11/2019  32.0    7.0    Tuesday
# 4  01/12/2019  33.0    8.4     Monday
# 5  01/16/2019  32.0    8.4    Tuesday
# 6  01/17/2019  33.0    8.4    Tuesday
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday
