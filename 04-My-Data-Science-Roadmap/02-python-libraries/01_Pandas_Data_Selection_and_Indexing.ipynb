# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\Admin\OneDrive\Desktop\Library Resources\Pandas\Pandas Session 1 Resources 16922586003.xlsx")
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Python_Library_Prac'

# %%
print(r"01\08\2025")
# Out:
# 01\08\2025

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (100, 9)

# %%
data.isnull()
# Out:
#     Region  Country  Item_Type  Sales_Channel  Order_Priority  Ship_Date  \
# 0    False    False      False          False           False      False
# 1    False    False      False          False           False      False
# 2    False    False      False          False           False      False
# 3    False    False      False          False           False      False
# 4    False    False      False          False           False      False
# ..     ...      ...        ...            ...             ...        ...
# 95   False    False      False          False           False      False
# 96   False    False      False          False           False      False
# 97   False    False      False          False           False      False
# 98   False    False      False          False           False      False
# 99   False    False      False          False           False      False
#
#     Unit_Cost  Total_Revenue  Total_Profit
# 0       False          False         False
# ...

# %%
data.isnull().any()
# Out:
# Region            False
# Country           False
# Item_Type         False
# Sales_Channel     False
# Order_Priority    False
# Ship_Date         False
# Unit_Cost         False
# Total_Revenue     False
# Total_Profit      False
# dtype: bool

# %%
data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
data.head(25)
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub_Saharan Africa                 Angola        Household
# 7                  Sub_Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub_Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %%
data.tail()
# Out:
#                 Region       Country      Item_Type Sales_Channel  \
# 95  Sub_Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub_Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub_Saharan Africa    Mozambique      Household       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 95              M 2011-03-09      35.84       97040.64      65214.72
# 96              L 2011-12-28       6.92       58471.11      15103.47
# 97              C 2016-06-29      90.93      228779.10      93748.05
# 98              M 2015-08-08      56.67      471336.91     144521.02
# 99              L 2012-02-15     502.54     3586605.09     889472.91

# %%
data.tail(7)
# Out:
#                                Region       Country      Item_Type  \
# 93                             Europe       Romania      Cosmetics
# 94  Central America and the Caribbean     Nicaragua      Beverages
# 95                 Sub_Saharan Africa          Mali        Clothes
# 96                               Asia      Malaysia         Fruits
# 97                 Sub_Saharan Africa  Sierra Leone     Vegetables
# 98                      North America        Mexico  Personal Care
# 99                 Sub_Saharan Africa    Mozambique      Household
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 93        Online              H 2010-12-25     263.33     3458252.00
# 94       Offline              C 2011-03-21      31.79      387002.20
# 95        Online              M 2011-03-09      35.84       97040.64
# 96       Offline              L 2011-12-28       6.92       58471.11
# 97       Offline              C 2016-06-29      90.93      228779.10
# ...

# %%
data[2:15]
# Out:
#                                Region                Country        Item_Type  \
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub_Saharan Africa                 Angola        Household
# 7                  Sub_Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub_Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# 11                 Sub_Saharan Africa             Cape Verde          Clothes
# 12                               Asia             Bangladesh          Clothes
# ...

# %%
data[2:25:3]
# Out:
#                    Region                Country        Item_Type  \
# 2                  Europe                 Russia  Office Supplies
# 5   Australia and Oceania        Solomon Islands        Baby Food
# 8      Sub_Saharan Africa  Republic of the Congo    Personal Care
# 11     Sub_Saharan Africa             Cape Verde          Clothes
# 14                   Asia               Mongolia    Personal Care
# 17     Sub_Saharan Africa               Cameroon        Beverages
# 20                 Europe                 Norway        Baby Food
# 23  Australia and Oceania            New Zealand           Fruits
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 2        Offline              L 2014-08-05     524.96     1158502.59
# 5         Online              C 2015-02-21     159.42      759202.72
# 8        Offline              M 2015-08-25      56.67      496101.10
# 11       Offline              H 2014-08-19      35.84      455479.04
# ...

# %%
a = {"":"","":"","":""}

# %%
type(data["Region"])
# Out:
# pandas.core.series.Series

# %%
data[["Region","Country"]][2:15]
# Out:
#                                Region                Country
# 2                              Europe                 Russia
# 3                  Sub_Saharan Africa  Sao Tome and Principe
# 4                  Sub_Saharan Africa                 Rwanda
# 5               Australia and Oceania        Solomon Islands
# 6                  Sub_Saharan Africa                 Angola
# 7                  Sub_Saharan Africa           Burkina Faso
# 8                  Sub_Saharan Africa  Republic of the Congo
# 9                  Sub_Saharan Africa                Senegal
# 10                               Asia             Kyrgyzstan
# 11                 Sub_Saharan Africa             Cape Verde
# 12                               Asia             Bangladesh
# 13  Central America and the Caribbean               Honduras
# 14                               Asia               Mongolia

# %%
data.loc[5,"Region"]
# Out:
# 'Australia and Oceania'

# %%
data.loc[[1,41,54,34,84],["Region","Country"]]
# Out:
#                                Region                Country
# 1   Central America and the Caribbean                Grenada
# 41       Middle East and North Africa             Azerbaijan
# 54                 Sub_Saharan Africa  Sao Tome and Principe
# 34                 Sub_Saharan Africa               Djibouti
# 84                 Sub_Saharan Africa                  Kenya

# %%
data["Region"]
# Out:
# 0                 Australia and Oceania
# 1     Central America and the Caribbean
# 2                                Europe
# 3                    Sub_Saharan Africa
# 4                    Sub_Saharan Africa
#                     ...
# 95                   Sub_Saharan Africa
# 96                                 Asia
# 97                   Sub_Saharan Africa
# 98                        North America
# 99                   Sub_Saharan Africa
# Name: Region, Length: 100, dtype: object

# %%
data.loc[41,["Region","Country","Item_Type","Sales_Channel"]]
# Out:
# Region           Middle East and North Africa
# Country                            Azerbaijan
# Item_Type                           Cosmetics
# Sales_Channel                          Online
# Name: 41, dtype: object

# %%
data.iloc[54,[0,1,2,3]]
# Out:
# Region              Sub_Saharan Africa
# Country          Sao Tome and Principe
# Item_Type                       Fruits
# Sales_Channel                  Offline
# Name: 54, dtype: object

# %%
data.loc[2,"Sales_Channel"] = "Online"

# %%
data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2        Online              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
data.iloc[2,3] = "Offline"

# %%
data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
data1 = data.copy()

# %%
data.loc[4,["Region","Country","Item_Type","Sales_Channel"]] = "Y" , "A" , "S" ,"H"

# %%
data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                                  Y                      A                S
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4             H              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
data.loc[7,["Region","Country","Sales_Channel"]] = ["Asia","India","Offline"]

# %%
data.loc[[7]]
# Out:
#   Region Country   Item_Type Sales_Channel Order_Priority  Ship_Date  \
# 7   Asia   India  Vegetables       Offline              H 2012-07-27
#
#    Unit_Cost  Total_Revenue  Total_Profit
# 7      90.93     1245112.92     510216.66

# %%
data["add"] = data["Region"] + " "+ data["Order_Priority"]

# %%
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                                   Y                      A                S
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
data["sum"] = data["Unit_Cost"] + data["Total_Revenue"]

# %%
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                                   Y                      A                S
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
data["new_unitcost"] = data["Unit_Cost"] / 2

# %%
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                                   Y                      A                S
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
data["new"] = range(100)

# %%
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                                   Y                      A                S
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit', 'add', 'sum',
#        'new_unitcost', 'new'],
#       dtype='object')

# %%
data = data[['Total_Revenue', 'Total_Profit', 'add', 'sum','Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
       'Ship_Date', 'Unit_Cost', 
       'new_unitcost', 'new']]

# %%
data
# Out:
#     Total_Revenue  Total_Profit                                  add  \
# 0      2533654.00     951410.50              Australia and Oceania H
# 1       576782.80     248406.36  Central America and the Caribbean C
# 2      1158502.59     224598.75                             Europe L
# 3        75591.66      19525.82                 Sub_Saharan Africa C
# 4      3296425.02     639077.50                                  Y L
# ..            ...           ...                                  ...
# 95       97040.64      65214.72                 Sub_Saharan Africa M
# 96       58471.11      15103.47                               Asia L
# 97      228779.10      93748.05                 Sub_Saharan Africa C
# 98      471336.91     144521.02                      North America M
# 99     3586605.09     889472.91                 Sub_Saharan Africa L
#
#            sum                             Region                Country  \
# ...

# %%
a = {
    "Region":"a",
    "Country":"b",
    "Item_Type":"c"
}

# %%
data.rename(columns=a)
# Out:
#     Total_Revenue  Total_Profit                                  add  \
# 0      2533654.00     951410.50              Australia and Oceania H
# 1       576782.80     248406.36  Central America and the Caribbean C
# 2      1158502.59     224598.75                             Europe L
# 3        75591.66      19525.82                 Sub_Saharan Africa C
# 4      3296425.02     639077.50                                  Y L
# ..            ...           ...                                  ...
# 95       97040.64      65214.72                 Sub_Saharan Africa M
# 96       58471.11      15103.47                               Asia L
# 97      228779.10      93748.05                 Sub_Saharan Africa C
# 98      471336.91     144521.02                      North America M
# 99     3586605.09     889472.91                 Sub_Saharan Africa L
#
#            sum                                  a                      b  \
# ...

# %%
data.loc[2:10,"Region":"new"]
# Out:
#                    Region                Country        Item_Type  \
# 2                  Europe                 Russia  Office Supplies
# 3      Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                       Y                      A                S
# 5   Australia and Oceania        Solomon Islands        Baby Food
# 6      Sub_Saharan Africa                 Angola        Household
# 7                    Asia                  India       Vegetables
# 8      Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9      Sub_Saharan Africa                Senegal           Cereal
# 10                   Asia             Kyrgyzstan       Vegetables
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  new_unitcost  new
# 2        Offline              L 2014-08-05     524.96       262.480    2
# 3         Online              C 2014-05-07       6.92         3.460    3
# 4              H              L 2013-06-02     524.96       262.480    4
# ...

# %%
data.iloc[2:10,4:12]
# Out:
#                   Region                Country        Item_Type  \
# 2                 Europe                 Russia  Office Supplies
# 3     Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                      Y                      A                S
# 5  Australia and Oceania        Solomon Islands        Baby Food
# 6     Sub_Saharan Africa                 Angola        Household
# 7                   Asia                  India       Vegetables
# 8     Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9     Sub_Saharan Africa                Senegal           Cereal
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  new_unitcost
# 2       Offline              L 2014-08-05     524.96       262.480
# 3        Online              C 2014-05-07       6.92         3.460
# 4             H              L 2013-06-02     524.96       262.480
# 5        Online              C 2015-02-21     159.42        79.710
# ...

# %%
string = "yash shah is the great"

# %%
string[0:10:2]
# Out:
# 'ys hh'

# %%
string[3:-6]
# Out:
# 'h shah is the'

# %%
data
# Out:
#     Total_Revenue  Total_Profit                                  add  \
# 0      2533654.00     951410.50              Australia and Oceania H
# 1       576782.80     248406.36  Central America and the Caribbean C
# 2      1158502.59     224598.75                             Europe L
# 3        75591.66      19525.82                 Sub_Saharan Africa C
# 4      3296425.02     639077.50                                  Y L
# ..            ...           ...                                  ...
# 95       97040.64      65214.72                 Sub_Saharan Africa M
# 96       58471.11      15103.47                               Asia L
# 97      228779.10      93748.05                 Sub_Saharan Africa C
# 98      471336.91     144521.02                      North America M
# 99     3586605.09     889472.91                 Sub_Saharan Africa L
#
#            sum                             Region                Country  \
# ...
