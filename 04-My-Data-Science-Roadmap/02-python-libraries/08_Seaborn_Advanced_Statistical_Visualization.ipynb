# %%
import seaborn as sns

# %%
import pandas as pd

# %%
tips = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\Library Resources\Seaborn\Seaborn Resourses16963287111.txt")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset("taxis")
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.relplot(x="tip",y="total_bill",hue="sex",style="time",data=tips)

# %%
sns.set_style("whitegrid")

# %%
sns.relplot(x="tip",y="total_bill",hue="smoker",style="day",data=tips)

# %%
sns.relplot(x="tip",y="total_bill",kind="line",marker="D",color="g",data=tips)

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,hue="sex")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,hue="sex",kind="hist")

# %%
sns.pairplot(tips,hue="sex")

# %%
sns.pairplot(tips,hue="total_bill")

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
a = tips[["total_bill","tip","size"]].corr()
a
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(a,annot=True,cmap="RdPu")
# Out:
# <Axes: >

# %%
sns.countplot(tips["day"],palette=["r","g","k","y"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20728\844215670.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(tips["day"],palette=["r","g","k","y"])
# <Axes: xlabel='count', ylabel='day'>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.displot(tips)

# %%
sns.displot(tips["day"])

# %%
sns.distplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.barplot(x="tip",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.barplot(x="day",y="total_bill",data=tips,palette=["r","g","k"])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="total_bill",y="day",data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x="total_bill",y="sex",data=tips,palette="rainbow")
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,palette="rainbow")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
