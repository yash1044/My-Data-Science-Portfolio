# %% [markdown]
# # Dict

# %%
d = {"A":54,"B":41,"C":17}

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
d.values()
# Out:
# dict_values([54, 41, 17])

# %%
d.items()
# Out:
# dict_items([('A', 54), ('B', 41), ('C', 17)])

# %%
d.get("A")
# Out:
# 54

# %%
d1 = {"A":54,"B":41,"C":17,"D":58,"E":16,"F":93,"G":57}

# %%
d1.update({"H":20})
d1
# Out:
# {'A': 54, 'B': 41, 'C': 17, 'D': 58, 'E': 16, 'F': 93, 'G': 57, 'H': 20}

# %%
d1.update({"G":59})
d1
# Out:
# {'A': 54, 'B': 41, 'C': 17, 'D': 58, 'E': 16, 'F': 93, 'G': 59, 'H': 20}

# %%
d1.pop("G")
# Out:
# 59

# %%
d1.popitem()
# Out:
# ('H', 20)

# %%
d1
# Out:
# {'A': 54, 'B': 41, 'C': 17, 'D': 58, 'E': 16, 'F': 93}

# %%
x = {"a":10,"b":20}

y = x.copy()
z = x

# %%
x.update({"c":30})
x,y,z
# Out:
# ({'a': 10, 'b': 20, 'c': 30}, {'a': 10, 'b': 20}, {'a': 10, 'b': 20, 'c': 30})

# %%
del x
y,z
# Out:
# ({'a': 10, 'b': 20}, {'a': 10, 'b': 20, 'c': 30})

# %%
dd = {"abc":"aaa","xyz":"xx"}

# %%
dd.clear()
dd
# Out:
# {}

# %%
a = ["yash","kuntal","alpesh"]
b = 10
c = [10,20,30]

# %%
dd.fromkeys(a,b)
# Out:
# {'yash': 10, 'kuntal': 10, 'alpesh': 10}

# %%
dd.fromkeys(a,c)
# Out:
# {'yash': [10, 20, 30], 'kuntal': [10, 20, 30], 'alpesh': [10, 20, 30]}

# %%
dd.fromkeys(c,a)
# Out:
# {10: ['yash', 'kuntal', 'alpesh'],
#  20: ['yash', 'kuntal', 'alpesh'],
#  30: ['yash', 'kuntal', 'alpesh']}

# %%
dd
dd.setdefault("abc")
dd
# Out:
# {'abc': None}
