# %%
l = ["ML","Stats","Python","DL","ML"]

# %% [markdown]
# ## count

# %%
l.count("ML")
# Out:
# 2

# %% [markdown]
# ## remove

# %%
l.remove("ML")
l
# Out:
# ['Stats', 'Python', 'DL', 'ML']

# %% [markdown]
# ## clear

# %%
l.clear()
l
# Out:
# []

# %% [markdown]
# ## sort

# %%
l = [238,97,45,30,87,12]
m = ['A','K','Y','N','J','P']
n = ['a','y','K','P','N','j'] 
o = ['A',51,'K',48]

# %%
l.sort()
l
# Out:
# [12, 30, 45, 87, 97, 238]

# %%
m.sort()
m
# Out:
# ['A', 'J', 'K', 'N', 'P', 'Y']

# %%
n.sort()
n
# Out:
# ['K', 'N', 'P', 'a', 'j', 'y']

# %% [markdown]
# o.sort() # in this int and str not sort one time

# %% [markdown]
# ## reverse

# %%
r1 = ['A','K','J','N','Y','P']

# %%
r1.reverse()
r1
# Out:
# ['P', 'Y', 'N', 'J', 'K', 'A']

# %%
r2 = ['A','K','Y','N','J','P']

# %%
r2.sort(reverse = False)
r2
# Out:
# ['A', 'J', 'K', 'N', 'P', 'Y']

# %%
r2.sort(reverse = True)
r2
# Out:
# ['Y', 'P', 'N', 'K', 'J', 'A']

# %% [markdown]
# ## index

# %%
r2.index("P")
# Out:
# 1

# %% [markdown]
# ## copy

# %%
a = [10,20,30,40]
b = a
c = a.copy()

# %%
a,b,c
# Out:
# ([10, 20, 30, 40], [10, 20, 30, 40], [10, 20, 30, 40])

# %%
a.append(50)
a,b,c
# Out:
# ([10, 20, 30, 40, 50], [10, 20, 30, 40, 50], [10, 20, 30, 40])

# %%
a.pop(1)
a,b,c
# Out:
# ([10, 30, 40, 50], [10, 30, 40, 50], [10, 20, 30, 40])

# %%
b.pop(1)
a,b,c
# Out:
# ([10, 40, 50], [10, 40, 50], [10, 20, 30, 40])

# %%
b.clear()
a,b,c
# Out:
# ([], [], [10, 20, 30, 40])

# %%
del b
a,c
# Out:
# ([], [10, 20, 30, 40])
