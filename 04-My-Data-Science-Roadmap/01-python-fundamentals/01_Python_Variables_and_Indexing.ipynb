# %% [markdown]
# # Python

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Variable

# %%
a = "Yash Shah" # string 
type(a),a
# Out:
# (str, 'Yash Shah')

# %%
b = 10
type(b),b
# Out:
# (int, 10)

# %% [markdown]
# # Variable Rules

# %%
myvar = "myvar"
MYVAR = "MYVAR"
myVar = "myVar"
my_var = "my_var"
myvar1 = "myvar1"
# This all are allowed

# %% [markdown]
# my var = ""
# $myvar = ""
# 1myvar = ""
# -- This is not allowed

# %% [markdown]
# # Index

# %%
mystr = "yash shah"
mystr
# Out:
# 'yash shah'

# %%
mystr[0] # index start from 0
# Out:
# 'y'

# %%
len(mystr) # length start from 1
# Out:
# 9

# %%
mystr[2],mystr[7]
# Out:
# ('s', 'a')

# %% [markdown]
# # Negative index

# %%
mystr[-1]
# Out:
# 'h'

# %%
mystr[-4]
# Out:
# 's'

# %% [markdown]
# # Slice

# %%
ft = "This is Python Class"

# %%
ft[2:14]
# Out:
# 'is is Python'

# %%
ft[14:2]
# Out:
# ''

# %%
ft[5:]
# Out:
# 'is Python Class'

# %%
ft[:14]
# Out:
# 'This is Python'

# %%
ft[:]
# Out:
# 'This is Python Class'

# %%
ft[-12:-2]
# Out:
# 'Python Cla'

# %%
ft[-2:-12]
# Out:
# ''

# %%
ft[3:-3]
# Out:
# 's is Python Cl'

# %% [markdown]
# # Jump

# %%
ft[2:12:2]
# Out:
# 'i sPt'

# %%
ft[-12:2:-1]
# Out:
# 'P si s'

# %%
ft[::-1]
# Out:
# 'ssalC nohtyP si sihT'

# %%
ft[-1::-1]
# Out:
# 'ssalC nohtyP si sihT'
