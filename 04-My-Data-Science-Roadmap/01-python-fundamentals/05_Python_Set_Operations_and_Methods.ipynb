# %%
s = {54,"yash",41,"yash"}
type(s),s
# Out:
# (set, {41, 54, 'yash'})

# %%
# s[1] index is not working

# %%
s.add("shah")
s
# Out:
# {41, 54, 'shah', 'yash'}

# %%
s.add(("nency","shah"))
s
# Out:
# {('nency', 'shah'), 41, 54, 'shah', 'yash'}

# %%
s.update("abc")
s
# Out:
# {('nency', 'shah'), 41, 54, 'a', 'b', 'c', 'shah', 'yash'}

# %%
s.update(("kuntal","shah"))
s
# Out:
# {('nency', 'shah'), 41, 54, 'a', 'b', 'c', 'kuntal', 'shah', 'yash'}

# %%
s.remove("a")
s
# Out:
# {('nency', 'shah'), 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'}

# %%
s.pop()
# Out:
# ('nency', 'shah')

# %%
# s.remove("alpesh") value is not exist so give an error

# %%
s.discard("alpesh") # value is not exist still not give an error

# %%
l = s
m = s.copy()
l,m,s
# Out:
# ({41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'})

# %%
s.add(1001)
l,m,s
# Out:
# ({1001, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {1001, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'})

# %%
l.add(408)
l,m,s
# Out:
# ({1001, 408, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {1001, 408, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'})

# %%
type(l)
# Out:
# set

# %%
m.add(100)
l,m,s
# Out:
# ({1001, 408, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {100, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  {1001, 408, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'})

# %%
m.clear()
l,m,s
# Out:
# ({1001, 408, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'},
#  set(),
#  {1001, 408, 41, 54, 'b', 'c', 'kuntal', 'shah', 'yash'})

# %%
s1 = {1,2,3,"hii"}
s2 = {3,4,5,"hello"}

# %%
s1.intersection(s2)
# Out:
# {3}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 'hello', 'hii'}

# %%
s1.difference(s2)
# Out:
# {1, 2, 'hii'}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 4, 5, 'hello', 'hii'}

# %%
s1.intersection_update(s2)
s1
# Out:
# {3}

# %%
s1.difference_update(s2)
s1
# Out:
# set()

# %%
s1.symmetric_difference_update(s2)
s1
# Out:
# {3, 4, 5, 'hello'}

# %%
a = {1,2,3,4,5,6}
b = {3,4,5}
c = {7,8,9}

# %%
a.issuperset(b)
# Out:
# True

# %%
a.issubset(b)
# Out:
# False

# %%
b.issubset(a)
# Out:
# True

# %%
a.isdisjoint(b)
# Out:
# False

# %%
a.isdisjoint(c)
# Out:
# True
