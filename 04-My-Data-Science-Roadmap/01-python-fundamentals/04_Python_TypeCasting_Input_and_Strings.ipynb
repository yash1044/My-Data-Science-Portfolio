# %% [markdown]
# # Type Caasting

# %%
a = 58
b = 41.54
c = "17"
d = "yash1001"

# %% [markdown]
# ## int to float

# %%
A = float(a)
type(A),A
# Out:
# (float, 58.0)

# %% [markdown]
# ## float to int

# %%
B = int(b)
type(B),B
# Out:
# (int, 41)

# %% [markdown]
# ## int to str

# %%
C = str(a)
type(C),C
# Out:
# (str, '58')

# %% [markdown]
# ## str to int

# %%
D = int(c)
type(D),D
# Out:
# (int, 17)

# %% [markdown]
# E = int(d) # its give an error caz not alphanumeric
# E

# %% [markdown]
# ## float to str

# %%
F = str(b)
type(F),F
# Out:
# (str, '41.54')

# %% [markdown]
# ## str to float

# %%
G = float(c)
type(G),G
# Out:
# (float, 17.0)

# %% [markdown]
# H = float(d) # its give an error caz not alphanumeric
# H

# %% [markdown]
# # Input Function

# %%
name = input("Enter Your Name")
print("my name is",name)
# Out:
# Enter Your Name yash
# my name is yash

# %%
age = input("Enter Your age")
print("your age is",age)
# Out:
# Enter Your age 22
# your age is 22

# %% [markdown]
# print("your age after 10 year is ",age+10) # this is not convert in str to int

# %%
age1 = int(input("Enter Your age"))
print("your age after 10 year is ",age1+10)
# Out:
# Enter Your age 22
# your age after 10 year is  32

# %%
num = int(input("Enter a number"))
print("Addition is ",num+5)
print("Substract is ",num-10)
print("Multiple is ",num*2)
print("Divide is ",num/2)
# Out:
# Enter a number 54
# Addition is  59
# Substract is  44
# Multiple is  108
# Divide is  27.0

# %% [markdown]
# # string

# %%
s = "yash the greatest shah"

# %%
type(s)
# Out:
# str

# %%
len(s)
# Out:
# 22

# %%
s[6]
# Out:
# 'h'

# %%
s[2:9]
# Out:
# 'sh the '

# %%
s.capitalize()
# Out:
# 'Yash the greatest shah'

# %%
s.title()
# Out:
# 'Yash The Greatest Shah'

# %%
s1 = s.upper()
s1
# Out:
# 'YASH THE GREATEST SHAH'

# %%
s1.lower()
# Out:
# 'yash the greatest shah'

# %%
s1.casefold()
# Out:
# 'yash the greatest shah'

# %%
s.count("h")
# Out:
# 4

# %%
s.count("sh")
# Out:
# 2

# %%
s.find("est")
# Out:
# 14

# %%
a = "my name is {} and surname is {}".format("yash","shah")
a
# Out:
# 'my name is yash and surname is shah'

# %%
s.endswith("ah")
# Out:
# True

# %%
s.startswith("yash")
# Out:
# True

# %%
A = "FRIENDS"
B = ":"
B.join(A)
# Out:
# 'F:R:I:E:N:D:S'

# %%
C = "   abc   "
C.rstrip(),C.lstrip(),C.strip()
# Out:
# ('   abc', 'abc   ', 'abc')

# %%
s.split()
# Out:
# ['yash', 'the', 'greatest', 'shah']

# %%
s2 = "yash-shah-great"

# %%
s2.split("-")
# Out:
# ['yash', 'shah', 'great']

# %%
s2.replace("yash","yash the")
# Out:
# 'yash the-shah-great'
