# %% [markdown]
# # List

# %%
l1 = ["ML","Stats","Python","DL"]

# %%
type(l1)
# Out:
# list

# %%
l2 = ["Tableau","powerBI"]

# %% [markdown]
# ## List index and slicer

# %%
l3= l1 + l2
l3
# Out:
# ['ML', 'Stats', 'Python', 'DL', 'Tableau', 'powerBI']

# %%
l3[3],l3[-2]
# Out:
# ('DL', 'Tableau')

# %%
l3[1:4],l3[2:-2]
# Out:
# (['Stats', 'Python', 'DL'], ['Python', 'DL'])

# %%
l3[0:4:2],l3[-2::-1]
# Out:
# (['ML', 'Python'], ['Tableau', 'DL', 'Python', 'Stats', 'ML'])

# %% [markdown]
# ## List Functionality

# %% [markdown]
# ### append

# %%
l1.append(l2) # add one singleton value atlast
l1
# Out:
# ['ML', 'Stats', 'Python', 'DL', ['Tableau', 'powerBI']]

# %% [markdown]
# ### extend

# %%
l1.extend(l2) # add one singletone value differntly atlast
l1
# Out:
# ['ML', 'Stats', 'Python', 'DL', ['Tableau', 'powerBI'], 'Tableau', 'powerBI']

# %%
l1.append("AI")
l1
# Out:
# ['ML',
#  'Stats',
#  'Python',
#  'DL',
#  ['Tableau', 'powerBI'],
#  'Tableau',
#  'powerBI',
#  'AI']

# %%
l1.extend("AI")
l1
# Out:
# ['ML',
#  'Stats',
#  'Python',
#  'DL',
#  ['Tableau', 'powerBI'],
#  'Tableau',
#  'powerBI',
#  'AI',
#  'A',
#  'I']

# %% [markdown]
# l1.append("yash","shah")
# l1.extend("yash","shah") # give an error

# %% [markdown]
# ### insert

# %%
l1.insert(2,"AI") # insert a value in perticular index
l1
# Out:
# ['ML',
#  'Stats',
#  'AI',
#  'Python',
#  'DL',
#  ['Tableau', 'powerBI'],
#  'Tableau',
#  'powerBI',
#  'AI',
#  'A',
#  'I']

# %% [markdown]
# ### pop

# %%
l1.pop() # remove last index value
# Out:
# 'I'

# %%
l1.pop(1) # remove at perticular index
# Out:
# 'Stats'

# %%
del l1 # delete whole l1
