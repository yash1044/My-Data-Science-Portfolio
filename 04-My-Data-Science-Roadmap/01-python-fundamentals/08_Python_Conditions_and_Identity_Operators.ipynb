# %%
t = (54,41,"yash")

# %%
54 in t
# Out:
# True

# %%
dict = {"a":10,"b":20,"c":30}
"a" in dict
# Out:
# True

# %%
a = 54
b = 41
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
a = 10 
if a<20:
    print("hi")
else:
    print("hello")
# Out:
# hi

# %%
age = int(input("enter age"))
if age >= 18:
    print("you can vote")
else:
    print("you cant vote")
# Out:
# enter age 22
# you can vote

# %%
temp = int(input("enter temp"))
if temp >= 40:
    print("very hot")
elif temp >= 30:
    print("hot")
elif temp >= 20:
    print("warm")
elif temp >= 10:
    print("cold")
else:
    print("very cold")
# Out:
# enter temp 32
# hot

# %%
num = int(input("enter number"))

if num == 1:
    print("jan")
elif num == 2:
    print("feb")
elif num == 3:
    print("mar")
elif num == 4:
    print("april")
elif num == 5:
    print("may")
elif num == 6:
    print("jun")
elif num == 7:
    print("jul")
elif num == 8:
    print("aug")
elif num == 9:
    print("sept")
elif num == 10:
    print("oct")
elif num == 11:
    print("nov")
elif num == 12:
    print("dec")
else:
    print("invalid")
# Out:
# enter number 54
# invalid

# %%
b = 15
if b %5 == 0:
    print("it is divisable by 5")
else:
    print("it is not divisable by 5")
# Out:
# it is divisable by 5

# %%
c = 54
if c %2 == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
marks = int(input("enter marks"))

if marks > 100 or marks < 0:
    print("invalid marks")
elif marks >90:
    print("a+")
elif marks >80:
    print("a")
elif marks >70:
    print("b")
elif marks >60:
    print("c")
elif marks >50:
    print("d")
else:
    print("fail")
# Out:
# enter marks 84
# a

# %%
a = 54
if a>10 and a%2 == 0:
    print("even and > 0")
else:
    print("odd or not > 0")
# Out:
# even and > 0

# %%
b = int(input("enter age"))
c = input("enter native")
if b >= 18 and c.lower() == "india":
    print("you can vote")
else:
    print("you cant")
# Out:
# enter age 22
# enter native -5
# you cant

# %%
abc = 41

if abc %2 != 0:
    print("odd")
# Out:
# odd
