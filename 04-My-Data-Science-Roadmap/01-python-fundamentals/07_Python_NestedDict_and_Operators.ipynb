# %% [markdown]
# # Nested dictionary

# %%
DS ={
"Programming": {"name":["SQL","Python"],"software":["MySQL","Jupyter"]},
"Manipulation":{"name":["Excel","pandas"],"software":["MsExcel","VS"]},
"Visulization":{"name":["Tableau","PBI"],"software":["Tableau Public","PBI Desktop"]}
 }

# %%
DS.keys()
# Out:
# dict_keys(['Programming', 'Manipulation', 'Visulization'])

# %%
DS.values()
# Out:
# dict_values([{'name': ['SQL', 'Python'], 'software': ['MySQL', 'Jupyter']}, {'name': ['Excel', 'pandas'], 'software': ['MsExcel', 'VS']}, {'name': ['Tableau', 'PBI'], 'software': ['Tableau Public', 'PBI Desktop']}])

# %% [markdown]
# ## Change MsExcel to Microsoft 365 in Manipulation

# %%
DS["Manipulation"]["software"][0] = "Microsoft 365"
DS
# Out:
# {'Programming': {'name': ['SQL', 'Python'], 'software': ['MySQL', 'Jupyter']},
#  'Manipulation': {'name': ['Excel', 'pandas'],
#   'software': ['Microsoft 365', 'VS']},
#  'Visulization': {'name': ['Tableau', 'PBI'],
#   'software': ['Tableau Public', 'PBI Desktop']}}

# %%
ds = {"Programming": {"name":{"SQL","Python"},"software":{"MySQL","Jupyter"}},
      "Manipulation":{"name":{"Excel","pandas"},"software":{"MsExcel","VS"}},
      "Visulization":{"name":{"Tableau","PBI"},"software":{"Tableau Public","PBI Desktop"}}
}

# %%
ds["Manipulation"]["software"].remove("MsExcel")

# %%
ds["Manipulation"]["software"].add("microsoft 365")
ds
# Out:
# {'Programming': {'name': {'Python', 'SQL'}, 'software': {'Jupyter', 'MySQL'}},
#  'Manipulation': {'name': {'Excel', 'pandas'},
#   'software': {'VS', 'microsoft 365'}},
#  'Visulization': {'name': {'PBI', 'Tableau'},
#   'software': {'PBI Desktop', 'Tableau Public'}}}

# %% [markdown]
# ## Task 1 Add R in Programming

# %%
DS2 ={
"Programming": {"name":{"SQL","Python"},"software":["MySQL","Jupyter"]},
"Manipulation":{"name":["Excel","pandas"],"software":["MsExcel","VS"]},
"Visulization":{"name":("Tableau","PBI"),"software":["Tableau Public","PBI Desktop"]}
 }

# %%
DS2["Programming"]["name"].add("R")
DS2
# Out:
# {'Programming': {'name': {'Python', 'R', 'SQL'},
#   'software': ['MySQL', 'Jupyter']},
#  'Manipulation': {'name': ['Excel', 'pandas'], 'software': ['MsExcel', 'VS']},
#  'Visulization': {'name': ('Tableau', 'PBI'),
#   'software': ['Tableau Public', 'PBI Desktop']}}

# %% [markdown]
# ## Task2 change name in Visulization

# %%
t = list(DS2["Visulization"]["name"])
t[1]="powerBI"
DS2["Visulization"]["name"] = tuple(t)
DS2
# Out:
# {'Programming': {'name': {'Python', 'R', 'SQL'},
#   'software': ['MySQL', 'Jupyter']},
#  'Manipulation': {'name': ['Excel', 'pandas'], 'software': ['MsExcel', 'VS']},
#  'Visulization': {'name': ('Tableau', 'powerBI'),
#   'software': ['Tableau Public', 'PBI Desktop']}}

# %% [markdown]
# # Operators

# %% [markdown]
# ## Arithmetic Operator

# %%
print(54%41)
print(8**4)
print(4//3)
print(4/3)
# Out:
# 13
# 4096
# 1
# 1.3333333333333333

# %% [markdown]
# ## Assignment Operator

# %%
y = 54
y += 41
y -= 17
y *= 16
y /= 58
y //= 10.01
y **= 4
y %= 2
y += 1
y
# Out:
# 1.0

# %% [markdown]
# ## Comparision Operator

# %%
a = 54
b = 41 

# a = 1001
# b = 1001 

print(a == b)
print(a >= b)
print(a <= b)
print(a > b)
print(a < b)
print(a != b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ## Logical Operator

# %%
A = 54
B = 41

print(a>0 and B<0)
print(a>0 or b<0)
print(a>0)

c = a>0 or b<0
print(not c)
# Out:
# False
# True
# True
# False
