# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\ML\ML-4 Feature Scaling Resource16994544271 (1).txt")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data["Pregnancies"])
# Out:
# (array([246., 178., 125.,  50.,  83.,  52.,  11.,  19.,   3.,   1.]),
#  array([ 0. ,  1.7,  3.4,  5.1,  6.8,  8.5, 10.2, 11.9, 13.6, 15.3, 17. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Glucose"])
# Out:
# (array([  5.,   0.,   4.,  32., 156., 211., 163.,  95.,  56.,  46.]),
#  array([  0. ,  19.9,  39.8,  59.7,  79.6,  99.5, 119.4, 139.3, 159.2,
#         179.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale = MinMaxScaler()

# %%
scale.fit_transform(data[["Pregnancies","Glucose"]])
# Out:
# array([[0.35294118, 0.74371859],
#        [0.05882353, 0.42713568],
#        [0.47058824, 0.91959799],
#        ...,
#        [0.29411765, 0.6080402 ],
#        [0.05882353, 0.63316583],
#        [0.05882353, 0.46733668]])

# %%
data[["Pregnancies1","Glucose1"]] = scale.fit_transform(data[["Pregnancies","Glucose"]])

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Pregnancies1  Glucose1
# ...

# %%
data["Pregnancies"].min(),data["Pregnancies"].max()
# Out:
# (0, 17)

# %%
data["Pregnancies1"].min(),data["Pregnancies1"].max()
# Out:
# (0.0, 1.0)

# %%
import seaborn as sns

# %%
plt.subplot(1,2,1)
sns.kdeplot(data["Pregnancies"])
sns.kdeplot(data["Glucose"])

plt.subplot(1,2,2)
sns.kdeplot(data["Pregnancies1"])
sns.kdeplot(data["Glucose1"])
# Out:
# <Axes: xlabel='Pregnancies1', ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale1 = StandardScaler()

# %%
scale1.fit_transform(data[["BloodPressure","SkinThickness"]])
# Out:
# array([[ 0.14964075,  0.90726993],
#        [-0.16054575,  0.53090156],
#        [-0.26394125, -1.28821221],
#        ...,
#        [ 0.14964075,  0.15453319],
#        [-0.47073225, -1.28821221],
#        [ 0.04624525,  0.65635768]])

# %%
data[["BloodPressure1","SkinThickness1"]] = scale1.fit_transform(data[["BloodPressure","SkinThickness"]])

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Pregnancies1  Glucose1  \
# ...

# %%
plt.subplot(1,2,1)
sns.kdeplot(data["BloodPressure"])
sns.kdeplot(data["SkinThickness"])

plt.subplot(1,2,2)
sns.kdeplot(data["BloodPressure1"])
sns.kdeplot(data["SkinThickness1"])
# Out:
# <Axes: xlabel='BloodPressure1', ylabel='Density'>

# %%
from sklearn.preprocessing import RobustScaler

# %%
scale3 = RobustScaler()

# %%
s3 = scale3.fit_transform(data[["Insulin","BMI"]])
s3
# Out:
# array([[-0.23968566,  0.17204301],
#        [-0.23968566, -0.58064516],
#        [-0.23968566, -0.93548387],
#        ...,
#        [ 0.64047151, -0.62365591],
#        [-0.23968566, -0.20430108],
#        [-0.23968566, -0.17204301]])

# %%
data[["Insulin1","BMI1"]] = s3

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Pregnancies1  Glucose1  \
# ...

# %%
plt.subplot(1,2,1)
sns.kdeplot(data["Insulin"],color="red")
sns.kdeplot(data["BMI"],color="green")

plt.subplot(1,2,2)
sns.kdeplot(data["Insulin1"],color="red")
sns.kdeplot(data["BMI1"],color="green")
# Out:
# <Axes: xlabel='Insulin1', ylabel='Density'>
