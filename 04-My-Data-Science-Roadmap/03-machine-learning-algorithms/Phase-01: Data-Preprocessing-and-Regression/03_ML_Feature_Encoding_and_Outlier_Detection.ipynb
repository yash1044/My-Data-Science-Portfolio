# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\ML\ML-3 Feature Encoding Resource16931320640.txt")
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
a = ["none","medium","very high","low","high"]

# %%
data = pd.DataFrame(a,columns=["yash"])

# %%
data
# Out:
#         yash
# 0       none
# 1     medium
# 2  very high
# 3        low
# 4       high

# %%
b = [0,2,4,1,3]

# %%
data["en_val"] = b

# %%
data
# Out:
#         yash  en_val
# 0       none       0
# 1     medium       2
# 2  very high       4
# 3        low       1
# 4       high       3

# %%
data
# Out:
#         yash  en_val
# 0       none       0
# 1     medium       2
# 2  very high       4
# 3        low       1
# 4       high       3

# %%
data.replace(a,b)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_960\1936185244.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace(a,b)
#    yash  en_val
# 0     0       0
# 1     2       2
# 2     4       4
# 3     1       1
# 4     3       3

# %%
c = ["S","M","L","S","M","L","S","M","L","S","M","L","S","M","L"]

# %%
data = pd.DataFrame(c)

# %%
data
# Out:
#     0
# 0   S
# 1   M
# 2   L
# 3   S
# 4   M
# 5   L
# 6   S
# 7   M
# 8   L
# 9   S
# 10  M
# 11  L
# 12  S
# 13  M
# 14  L

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit_transform(data[0])
# Out:
# array([2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0])

# %%
data["en_val"] = le.fit_transform(data[0])

# %%
data
# Out:
#     0  en_val
# 0   S       2
# 1   M       1
# 2   L       0
# 3   S       2
# 4   M       1
# 5   L       0
# 6   S       2
# 7   M       1
# 8   L       0
# 9   S       2
# 10  M       1
# 11  L       0
# 12  S       2
# 13  M       1
# 14  L       0

# %%
data.drop(0,axis=1,inplace=True)

# %%
data
# Out:
#     en_val
# 0        2
# 1        1
# 2        0
# 3        2
# 4        1
# 5        0
# 6        2
# 7        1
# 8        0
# 9        2
# 10       1
# 11       0
# 12       2
# 13       1
# 14       0

# %%
data
# Out:
#     en_val
# 0        2
# 1        1
# 2        0
# 3        2
# 4        1
# 5        0
# 6        2
# 7        1
# 8        0
# 9        2
# 10       1
# 11       0
# 12       2
# 13       1
# 14       0

# %%
le.inverse_transform([0,1,2])
# Out:
# array(['L', 'M', 'S'], dtype=object)

# %%
le.inverse_transform(data["en_val"])
# Out:
# array(['S', 'M', 'L', 'S', 'M', 'L', 'S', 'M', 'L', 'S', 'M', 'L', 'S',
#        'M', 'L'], dtype=object)

# %%
data
# Out:
#     en_val
# 0        2
# 1        1
# 2        0
# 3        2
# 4        1
# 5        0
# 6        2
# 7        1
# 8        0
# 9        2
# 10       1
# 11       0
# 12       2
# 13       1
# 14       0

# %%
data["en_val"].unique()
# Out:
# array([2, 1, 0])

# %%
data.describe()
# Out:
#           en_val
# count  15.000000
# mean    1.000000
# std     0.845154
# min     0.000000
# 25%     0.000000
# 50%     1.000000
# 75%     2.000000
# max     2.000000

# %%
data = pd.get_dummies(data["en_val"])

# %%
data
# Out:
#         0      1      2
# 0   False  False   True
# 1   False   True  False
# 2    True  False  False
# 3   False  False   True
# 4   False   True  False
# 5    True  False  False
# 6   False  False   True
# 7   False   True  False
# 8    True  False  False
# 9   False  False   True
# 10  False   True  False
# 11   True  False  False
# 12  False  False   True
# 13  False   True  False
# 14   True  False  False

# %%
c
# Out:
# ['S', 'M', 'L', 'S', 'M', 'L', 'S', 'M', 'L', 'S', 'M', 'L', 'S', 'M', 'L']

# %%
c = pd.DataFrame(c)
c
# Out:
#     0
# 0   S
# 1   M
# 2   L
# 3   S
# 4   M
# 5   L
# 6   S
# 7   M
# 8   L
# 9   S
# 10  M
# 11  L
# 12  S
# 13  M
# 14  L

# %%
data["val"] = c

# %%
data
# Out:
#         0      1      2 val
# 0   False  False   True   S
# 1   False   True  False   M
# 2    True  False  False   L
# 3   False  False   True   S
# 4   False   True  False   M
# 5    True  False  False   L
# 6   False  False   True   S
# 7   False   True  False   M
# 8    True  False  False   L
# 9   False  False   True   S
# 10  False   True  False   M
# 11   True  False  False   L
# 12  False  False   True   S
# 13  False   True  False   M
# 14   True  False  False   L

# %%
data.drop("val",axis=1,inplace=True)

# %%
data
# Out:
#         0      1      2
# 0   False  False   True
# 1   False   True  False
# 2    True  False  False
# 3   False  False   True
# 4   False   True  False
# 5    True  False  False
# 6   False  False   True
# 7   False   True  False
# 8    True  False  False
# 9   False  False   True
# 10  False   True  False
# 11   True  False  False
# 12  False  False   True
# 13  False   True  False
# 14   True  False  False

# %%
pd.concat([data,c],axis=1)
# Out:
#         0      1      2  0
# 0   False  False   True  S
# 1   False   True  False  M
# 2    True  False  False  L
# 3   False  False   True  S
# 4   False   True  False  M
# 5    True  False  False  L
# 6   False  False   True  S
# 7   False   True  False  M
# 8    True  False  False  L
# 9   False  False   True  S
# 10  False   True  False  M
# 11   True  False  False  L
# 12  False  False   True  S
# 13  False   True  False  M
# 14   True  False  False  L

# %%
data = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\ML\ML-3 Feature Encoding Resource16931320640.txt")

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data["marital-status"].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Widowed', 'Divorced',
#        'Separated', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
le.fit_transform(data["marital-status"])
# Out:
# array([4, 2, 2, ..., 6, 4, 2])

# %%
data["marital-status"] = le.fit_transform(data["marital-status"])

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num  marital-status  \
# 0   25    Private  226802          11th                7               4
# 1   38    Private   89814       HS-grad                9               2
# 2   28  Local-gov  336951    Assoc-acdm               12               2
# 3   44    Private  160323  Some-college               10               2
# 4   18          ?  103497  Some-college               10               4
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
le.inverse_transform([4])
# Out:
# array(['Never-married'], dtype=object)
