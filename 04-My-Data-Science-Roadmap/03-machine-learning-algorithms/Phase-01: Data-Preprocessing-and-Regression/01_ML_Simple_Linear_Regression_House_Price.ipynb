# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\ML\ML-1 Simple Linear Regression Resource16931312390.txt")

# %%
x = data.drop("price",axis=1)
y = data["price"]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,marker="1",ms=15,color="r")
plt.xlabel("x-ax")
plt.ylabel("y-ax")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model.predict(x)
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
model.intercept_ #m
# Out:
# np.float64(180616.43835616432)

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
135.78767123 * 2000 + 180616.43835616432 # y = m * x +c
# Out:
# 452191.78081616433

# %%
model.predict([[2000],[3000],[4000]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([452191.78082192, 587979.45205479, 723767.12328767])

# %%
model.predict([[2000],[3000],[4000]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([452191.78082192, 587979.45205479, 723767.12328767])

# %%
import warnings as w
w.filterwarnings("ignore")

# %%
ypri = model.predict(x)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y,ypri)*100
# Out:
# 95.84301138199486

# %%
from sklearn.metrics import mean_squared_error

# %%
a = mean_squared_error(y,ypri)
a
# Out:
# 186815068.4931509

# %%
import numpy as np

# %%
np.sqrt(a)
# Out:
# np.float64(13668.030893042014)

# %%
from sklearn.metrics import root_mean_squared_error

# %%
root_mean_squared_error(y,ypri)
# Out:
# 13668.030893042014

# %%
model.predict([[2000]])
# Out:
# array([452191.78082192])

# %% [markdown]
# # for just knowladge how to find r2scoee and rmse

# %%
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
ypri
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
data["pri"] = ypri

# %%
data
# Out:
#    area   price            pri
# 0  2600  550000  533664.383562
# 1  3000  565000  587979.452055
# 2  3200  610000  615136.986301
# 3  3600  680000  669452.054795
# 4  4000  725000  723767.123288

# %%
data["squere"] = (data["price"] - data["pri"]) ** 2

# %%
data
# Out:
#    area   price            pri        squere
# 0  2600  550000  533664.383562  2.668524e+08
# 1  3000  565000  587979.452055  5.280552e+08
# 2  3200  610000  615136.986301  2.638863e+07
# 3  3600  680000  669452.054795  1.112591e+08
# 4  4000  725000  723767.123288  1.519985e+06

# %%
data["squere"].sum() / 5
# Out:
# np.float64(186815068.4931509)

# %%
np.sqrt(data["squere"].sum() / 5)
# Out:
# np.float64(13668.030893042014)

# %%
data["squere2"] = (data["price"] - data["price"].mean()) ** 2

# %%
data
# Out:
#    area   price            pri        squere       squere2
# 0  2600  550000  533664.383562  2.668524e+08  5.776000e+09
# 1  3000  565000  587979.452055  5.280552e+08  3.721000e+09
# 2  3200  610000  615136.986301  2.638863e+07  2.560000e+08
# 3  3600  680000  669452.054795  1.112591e+08  2.916000e+09
# 4  4000  725000  723767.123288  1.519985e+06  9.801000e+09

# %%
1-(data["squere"].sum()/data["squere2"].sum())
# Out:
# np.float64(0.9584301138199486)

# %%
r2_score(y,ypri)
# Out:
# 0.9584301138199486

# %%
X = np.array([1,2,3,4,5])

# %%
X.reshape(-1,1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
type(X.reshape(-1,1))
# Out:
# numpy.ndarray

# %%
X = np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([2,4,6,8,10])

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
y_pred
# Out:
# array([ 2.,  4.,  6.,  8., 10.])

# %%
model.intercept_
# Out:
# np.float64(-1.7763568394002505e-15)

# %%
model.coef_
# Out:
# array([2.])

# %%
2*(4) -1.7763568394002505e-15
# Out:
# 7.999999999999998

# %%
data
# Out:
#    area   price            pri        squere       squere2
# 0  2600  550000  533664.383562  2.668524e+08  5.776000e+09
# 1  3000  565000  587979.452055  5.280552e+08  3.721000e+09
# 2  3200  610000  615136.986301  2.638863e+07  2.560000e+08
# 3  3600  680000  669452.054795  1.112591e+08  2.916000e+09
# 4  4000  725000  723767.123288  1.519985e+06  9.801000e+09

# %%
data.drop("pri",axis=1)
# Out:
#    area   price        squere       squere2
# 0  2600  550000  2.668524e+08  5.776000e+09
# 1  3000  565000  5.280552e+08  3.721000e+09
# 2  3200  610000  2.638863e+07  2.560000e+08
# 3  3600  680000  1.112591e+08  2.916000e+09
# 4  4000  725000  1.519985e+06  9.801000e+09
