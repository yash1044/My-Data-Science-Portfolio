# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\ML\ML-6 Logistics Regression Files16958214402 (1).txt")

# %%
data
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
data.describe()
# Out:
#              age  bought_insurance
# count  27.000000         27.000000
# mean   39.666667          0.518519
# std    15.745573          0.509175
# min    18.000000          0.000000
# 25%    25.000000          0.000000
# 50%    45.000000          1.000000
# 75%    54.500000          1.000000
# max    62.000000          1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data["age"],data["bought_insurance"])

# %%
x = data.drop("bought_insurance",axis=1)
y = data["bought_insurance"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[48]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
model.predict([[18]])
# Out:
# array([0])

# %%
model.score(x_train,y_train)*100
# Out:
# 88.88888888888889

# %%
model.score(x_test,y_test)*100
# Out:
# 88.88888888888889

# %%
pri = model.predict(x_test)
pri
# Out:
# array([1, 0, 1, 0, 0, 0, 0, 1, 0])

# %%
y_test
# Out:
# 8     1
# 13    0
# 9     1
# 21    0
# 0     0
# 11    0
# 16    1
# 17    1
# 12    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.metrics import confusion_matrix

# %%
c = confusion_matrix(y_test,pri)
c
# Out:
# array([[5, 0],
#        [1, 3]])

# %%
sns.heatmap(c,annot=True)
# Out:
# <Axes: >
