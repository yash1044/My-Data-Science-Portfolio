# %% [markdown]
# # Airline Customer Satisfaction using Decision Tree
# # **Objective:** To classify and predict whether a passenger is satisfied or unsatisfied based on their flight experience and demographics.
# # **Techniques:** Data Wrangling, Outlier Detection, Label Encoding, Decision Tree Classification.

# %% [markdown]
# # Part-1: Data Exploration and Pre-processing

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\ML_Projects\ML_Project_2.txt")
data
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0                0           0   70172    Male     Loyal Customer   13
# 1                1           1    5047    Male  disloyal Customer   25
# 2                2           2  110028  Female     Loyal Customer   26
# 3                3           3   24026  Female     Loyal Customer   25
# 4                4           4  119299    Male     Loyal Customer   61
# ...            ...         ...     ...     ...                ...  ...
# 9995          9995        9995  124365    Male     Loyal Customer   50
# 9996          9996        9996   22044    Male     Loyal Customer   38
# 9997          9997        9997   14057  Female     Loyal Customer   39
# 9998          9998        9998  113848    Male     Loyal Customer   52
# 9999          9999        9999    1865  Female     Loyal Customer   41
#
#        Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0             id           Age  \
# count   10000.00000  10000.00000   10000.000000  10000.000000
# mean     4999.50000   4999.50000   64950.978500     39.303700
# std      2886.89568   2886.89568   37420.905082     15.116478
# min         0.00000      0.00000       8.000000      7.000000
# 25%      2499.75000   2499.75000   32330.500000     27.000000
# 50%      4999.50000   4999.50000   64941.000000     40.000000
# 75%      7499.25000   7499.25000   97579.750000     51.000000
# max      9999.00000   9999.00000  129863.000000     85.000000
#
#        Flight Distance  Inflight wifi service  \
# count     10000.000000           10000.000000
# mean       1198.823800               2.731500
# std        1001.774138               1.328226
# min          31.000000               0.000000
# 25%         413.000000               2.000000
# 50%         852.500000               3.000000
# 75%        1747.000000               4.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0.1                       10000 non-null  int64
#  1   Unnamed: 0                         10000 non-null  int64
#  2   id                                 10000 non-null  int64
#  3   Gender                             10000 non-null  object
#  4   Customer Type                      10000 non-null  object
#  5   Age                                10000 non-null  int64
#  6   Type of Travel                     10000 non-null  object
#  7   Class                              10000 non-null  object
#  8   Flight Distance                    10000 non-null  int64
#  9   Inflight wifi service              10000 non-null  int64
#  10  Departure/Arrival time convenient  10000 non-null  int64
# ...

# %%
data.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1,inplace=True)

# %%
data.columns = data.columns.str.replace(" ","_")

# %%
data.columns
# Out:
# Index(['id', 'Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data.head()
# Out:
#        id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight_Distance  Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease_of_Online_booking  ...  Inflight_entertainment  On-board_service  \
# ...

# %%
data["satisfaction"].unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Encoding

# %%
data["satisfaction"].replace({"neutral or dissatisfied":0,"satisfied":1})
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: satisfaction, Length: 10000, dtype: int64

# %%
data["satisfaction"].replace(["neutral or dissatisfied","satisfied"],[0,1])
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: satisfaction, Length: 10000, dtype: int64

# %%
data["satisfaction"] = data["satisfaction"].replace({"neutral or dissatisfied":0,"satisfied":1})

# %%
data.head()
# Out:
#        id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight_Distance  Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease_of_Online_booking  ...  Inflight_entertainment  On-board_service  \
# ...

# %%
data.groupby("satisfaction")["id"].count()
# Out:
# satisfaction
# 0    5689
# 1    4311
# Name: id, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(data["satisfaction"],height=0.2)
# Out:
# <BarContainer object of 10000 artists>

# %%
import seaborn as sns

# %%
sns.countplot(x='satisfaction', data=data)
plt.title("Customer Satisfaction Count")
plt.show()

# %%
data.groupby("Gender")["satisfaction"].mean()
# Out:
# Gender
# Female    0.424432
# Male      0.438062
# Name: satisfaction, dtype: float64

# %%
data.groupby("Age")["satisfaction"].mean()
# Out:
# Age
# 7     0.071429
# 8     0.081967
# 9     0.194030
# 10    0.137255
# 11    0.115942
#         ...
# 76    0.000000
# 77    0.222222
# 79    0.666667
# 80    0.111111
# 85    0.000000
# Name: satisfaction, Length: 74, dtype: float64

# %%
data.groupby("Food_and_drink")["satisfaction"].mean()
# Out:
# Food_and_drink
# 0    0.625000
# 1    0.198142
# 2    0.362305
# 3    0.404990
# 4    0.515050
# 5    0.566176
# Name: satisfaction, dtype: float64

# %%
plt.boxplot(data["Flight_Distance"])
plt.title("Flight_Distance distribution")
plt.show()

# %%
plt.boxplot(data["Checkin_service"])
plt.title("Checkin_service distribution")
plt.show()

# %%
data.isnull().sum()
# Out:
# id                                    0
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# Departure_Delay_in_Minutes            0
# Arrival_Delay_in_Minutes             26
# ...

# %%
data = data.dropna() # drop null values

# %%
data.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# satisfaction                         0
# dtype: int64

# %%
data["Flight_Distance"].unique()
# Out:
# array([ 460,  235, 1142, ..., 3033, 1319, 1443])

# %%
len(data["Flight_Distance"].unique())
# Out:
# 2430

# %% [markdown]
# # Part-2: Working with models

# %%
data.head(2)
# Out:
#       id Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0  70172   Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1   5047   Male  disloyal Customer   25  Business travel  Business
#
#    Flight_Distance  Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
#
#    Ease_of_Online_booking  ...  Inflight_entertainment  On-board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
#
#    Leg_room_service  Baggage_handling  Checkin_service  Inflight_service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
#
#    Cleanliness  Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  \
# ...

# %%
data["Class"].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data["Gender"] = le.fit_transform(data["Gender"])
data['Customer_Type'] = le.fit_transform(data['Customer_Type'])
data['Type_of_Travel'] = le.fit_transform(data['Type_of_Travel'])
data['Class'] = le.fit_transform(data['Class'])

# %%
data.head(3)
# Out:
#        id  Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0   70172       1              0   13               1      2              460
# 1    5047       1              1   25               0      0              235
# 2  110028       0              0   26               0      0             1142
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
#
#    Ease_of_Online_booking  ...  Inflight_entertainment  On-board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
#
#    Leg_room_service  Baggage_handling  Checkin_service  Inflight_service  \
# ...

# %% [markdown]
# ### Devide target variable and features

# %%
x = data.drop("satisfaction",axis=1)
y = data["satisfaction"]

# %%
data.hist()
plt.show()

# %% [markdown]
# ### scaling on features data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[ 0.139117  ,  1.022101  , -0.46815207, ...,  1.31151575,
#          0.2672691 ,  0.07106403],
#        [-1.60136642,  1.022101  ,  2.13605805, ..., -1.71598135,
#         -0.3602227 , -0.23814858],
#        [ 1.20427949, -0.9783769 , -0.46815207, ...,  1.31151575,
#         -0.38636819, -0.39275488],
#        ...,
#        [-1.36057171, -0.9783769 , -0.46815207, ..., -0.95910708,
#         -0.38636819, -0.39275488],
#        [ 1.30637003,  1.022101  , -0.46815207, ...,  1.31151575,
#         -0.3602227 , -0.10930999],
#        [-1.68640624, -0.9783769 , -0.46815207, ...,  0.55464148,
#         -0.38636819, -0.39275488]])

# %% [markdown]
# ### Splitting data by train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %% [markdown]
# ### Model training

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(
    criterion='gini',
    max_depth=5,
    min_samples_split=5
)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=5)

# %%
model.score(x_train,y_train)
# Out:
# 0.9047499686677528

# %%
model.score(x_test,y_test)
# Out:
# 0.9057644110275689

# %% [markdown]
# ### Model Evalution

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score
from sklearn.metrics import classification_report,confusion_matrix,f1_score

# %%
def evaluate_model(y_test, y_pred):
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1 Score:", f1_score(y_test, y_pred))

    print("\nClassification Report:\n")
    print(classification_report(y_test, y_pred))

    print("\nConfusion Matrix:\n")
    print(confusion_matrix(y_test, y_pred))

# %%
ypri = model.predict(x_test)

# %%
evaluate_model(y_test,ypri)
# Out:
# Accuracy: 0.9057644110275689
# Precision: 0.901307966706302
# Recall: 0.8783314020857474
# F1 Score: 0.8896713615023474
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      1132
#            1       0.90      0.88      0.89       863
#
#     accuracy                           0.91      1995
#    macro avg       0.91      0.90      0.90      1995
# weighted avg       0.91      0.91      0.91      1995
#
#
# Confusion Matrix:
#
# [[1049   83]
#  [ 105  758]]

# %% [markdown]
# ### Plot Tree

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(model, filled=True)
plt.show()
